# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get( "https://www.olx.in/pune_g4059014/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH, '//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
    
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years)
# Out:
# (40, 40, 40, 40)

# %%
import pandas as pd 
df1 = pd.DataFrame({'Name':property_Name,'Types':Type,'Prices':prices,'Years':years})
df1
# Out:
#                                  Name                      Types  \
# 0                   MARKET YARD, PUNE    2 Bds - 2 Ba - 1186 ft2
# 1   CANTONMENT RESIDENTIAL AREA, PUNE    2 Bds - 2 Ba - 1186 ft2
# 2                       YERWADA, PUNE    1 Bds - 2 Ba - 1000 ft2
# 3                       YERWADA, PUNE     1 Bds - 1 Ba - 350 ft2
# 4                 VISHRANT WADI, PUNE     1 Bds - 1 Ba - 719 ft2
# 5                        DECCAN, PUNE    2 Bds - 2 Ba - 1148 ft2
# 6   CANTONMENT RESIDENTIAL AREA, PUNE     1 Bds - 1 Ba - 530 ft2
# 7                 KOREGAON PARK, PUNE  4+ Bds - 4+ Ba - 6000 ft2
# 8                 KALYANI NAGAR, PUNE   4 Bds - 4+ Ba - 2700 ft2
# 9                 KOREGAON PARK, PUNE    3 Bds - 3 Ba - 1610 ft2
# 10                KALYANI NAGAR, PUNE    2 Bds - 2 Ba - 1100 ft2
# 11                KOREGAON PARK, PUNE     1 Bds - 1 Ba - 850 ft2
# 12                 PRATIK NAGAR, PUNE    2 Bds - 2 Ba - 1100 ft2
# ...

# %%
driver = webdriver.Chrome()

# %%
driver.get( "https://www.olx.in/mumbai_g4058997/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
    
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years)
# Out:
# (40, 39, 40, 40)

# %%
import pandas as pd 
df = pd.DataFrame({'Name':property_Name,'Prices':prices,'Years':years})
df
# Out:
#                        Name         Prices       Years
# 0           DHARAVI, MUMBAI     ₹ 5,00,000      JUN 05
# 1        KURLA EAST, MUMBAI    ₹ 62,00,000  3 DAYS AGO
# 2         SION EAST, MUMBAI  ₹ 1,60,00,000      MAY 28
# 3   VILE PARLE WEST, MUMBAI  ₹ 1,10,00,000       TODAY
# 4             MAHIM, MUMBAI    ₹ 45,00,000       TODAY
# 5        KURLA EAST, MUMBAI    ₹ 78,00,000       TODAY
# 6        KURLA EAST, MUMBAI    ₹ 75,00,000       TODAY
# 7       BANDRA WEST, MUMBAI    ₹ 28,00,000       TODAY
# 8           CHEMBUR, MUMBAI    ₹ 90,00,000       TODAY
# 9        KURLA EAST, MUMBAI    ₹ 85,00,000       TODAY
# 10       KURLA EAST, MUMBAI    ₹ 89,11,250       TODAY
# 11       KURLA EAST, MUMBAI    ₹ 83,00,000       TODAY
# 12       KURLA EAST, MUMBAI    ₹ 84,24,000       TODAY
# 13       KURLA EAST, MUMBAI    ₹ 87,00,000       TODAY
# 14       KURLA EAST, MUMBAI    ₹ 86,50,000       TODAY
# 15       KURLA EAST, MUMBAI  ₹ 1,16,00,000       TODAY
# ...

# %%
import pandas as pd 
df2 = pd.DataFrame({'Type':Type})
df2
# Out:
#                          Type
# 0      1 Bds - 1 Ba - 250 ft2
# 1      2 Bds - 2 Ba - 900 ft2
# 2      1 Bds - 1 Ba - 300 ft2
# 3      1 Bds - 2 Ba - 250 ft2
# 4      1 Bds - 2 Ba - 680 ft2
# 5      1 Bds - 2 Ba - 650 ft2
# 6      1 Bds - 2 Ba - 570 ft2
# 7      1 Bds - 2 Ba - 670 ft2
# 8      1 Bds - 2 Ba - 650 ft2
# 9      1 Bds - 2 Ba - 750 ft2
# 10     1 Bds - 2 Ba - 700 ft2
# 11     1 Bds - 2 Ba - 710 ft2
# 12     1 Bds - 2 Ba - 455 ft2
# 13     1 Bds - 2 Ba - 725 ft2
# 14     2 Bds - 2 Ba - 598 ft2
# 15    2 Bds - 2 Ba - 1090 ft2
# 16    2 Bds - 2 Ba - 1050 ft2
# 17     2 Bds - 2 Ba - 945 ft2
# 18     2 Bds - 2 Ba - 500 ft2
# 19     1 Bds - 1 Ba - 575 ft2
# 20     1 Bds - 2 Ba - 540 ft2
# 21     1 Bds - 1 Ba - 305 ft2
# 22     1 Bds - 1 Ba - 634 ft2
# 23    4 Bds - 4 Ba - 1600 ft2
# 24     1 Bds - 1 Ba - 750 ft2
# 25     2 Bds - 2 Ba - 800 ft2
# 26     2 Bds - 2 Ba - 800 ft2
# 27  4+ Bds - 4+ Ba - 2700 ft2
# 28     1 Bds - 2 Ba - 710 ft2
# 29     1 Bds - 2 Ba - 661 ft2
# ...

# %%
data_frames = [df1, df2]

for i, df in enumerate(data_frames):
    print(f"DataFrame {i+1}:")
    print(df)
    print("\n")
# Out:
# DataFrame 1:
#                             Name         Prices      Years
# 0              SION EAST, MUMBAI  ₹ 1,60,00,000     MAY 28
# 1             KURLA WEST, MUMBAI  ₹ 1,30,00,000     MAY 24
# 2              KHAR EAST, MUMBAI    ₹ 25,00,000     JUN 06
# 3                CHEMBUR, MUMBAI    ₹ 99,00,000      TODAY
# 4            BANDRA WEST, MUMBAI  ₹ 2,95,00,000      TODAY
# 5             KURLA EAST, MUMBAI    ₹ 85,00,000      TODAY
# 6             KURLA EAST, MUMBAI    ₹ 89,11,250      TODAY
# 7             KURLA EAST, MUMBAI    ₹ 83,00,000      TODAY
# 8             KURLA EAST, MUMBAI    ₹ 84,24,000      TODAY
# 9             KURLA EAST, MUMBAI    ₹ 87,00,000      TODAY
# 10            KURLA EAST, MUMBAI    ₹ 86,50,000      TODAY
# 11            KURLA EAST, MUMBAI  ₹ 1,16,00,000      TODAY
# 12            KURLA EAST, MUMBAI  ₹ 1,25,00,000      TODAY
# 13            KURLA EAST, MUMBAI  ₹ 1,21,00,000      TODAY
# 14            UNION PARK, MUMBAI    ₹ 18,00,000      TODAY
# ...

# %%
driver.get( "https://www.olx.in/tamil-nadu_g2001173/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 40, 40, 40, 40)

# %%
import pandas as pd 
df2 = pd.DataFrame({'Name':property_Name,'Types':Type,'Prices':prices,'BHK':Bhk_type,'Years':years})
df2
# Out:
#                                            Name                      Types  \
# 0                         NUNGAMBAKKAM, CHENNAI    3 Bds - 2 Ba - 1244 ft2
# 1                           ADAMBAKKAM, CHENNAI    3 Bds - 2 Ba - 1250 ft2
# 2                        THANTHONI MALAI, KARUR    3 Bds - 4 Ba - 1750 ft2
# 3                      KOVILPALAYAM, COIMBATORE    2 Bds - 2 Ba - 1075 ft2
# 4                           MADHAVARAM, CHENNAI    3 Bds - 3 Ba - 1350 ft2
# 5                           MEDAVAKKAM, CHENNAI     2 Bds - 2 Ba - 982 ft2
# 6          KOVILAMBAKKAM KOVILAMBAKKAM, CHENNAI     2 Bds - 2 Ba - 758 ft2
# 7                       MUNEESWARI NAGAR, HOSUR    2 Bds - 2 Ba - 1500 ft2
# 8                              KCC NAGAR, HOSUR    2 Bds - 2 Ba - 1200 ft2
# 9                             TAMBARAM, CHENNAI     2 Bds - 3 Ba - 800 ft2
# 10        NEW WASHERMANPET ASHOK NAGAR, CHENNAI    3 Bds - 3 Ba - 1624 ft2
# ...

# %%
driver.get( "https://www.olx.in/gujarat_g2001154/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 39, 40, 40, 40)

# %%
import pandas as pd 
df3 = pd.DataFrame({'Name':property_Name,'Prices':prices,'BHK':Bhk_type,'Years':years})
df3
# Out:
#                             Name         Prices  \
# 0         ASHRAM ROAD, AHMEDABAD    ₹ 72,00,000
# 1             ZADESHWAR, BHARUCH    ₹ 29,00,000
# 2         GAURAVPATH ROAD, SURAT    ₹ 41,82,000
# 3             THALTEJ, AHMEDABAD  ₹ 5,30,00,000
# 4            JAGATPUR, AHMEDABAD    ₹ 77,00,000
# 5     RANGDARSHAN SOCIETY, SURAT    ₹ 55,00,000
# 6   ANAND VIDYANAGAR ROAD, ANAND    ₹ 15,00,000
# 7               NIKOL, AHMEDABAD    ₹ 45,00,000
# 8                   UDHNA, SURAT    ₹ 60,00,000
# 9          GUNATIT NAGAR, RAJKOT    ₹ 25,00,000
# 10            GADKHOL, ANKLESVAR    ₹ 75,00,000
# 11              SHELA, AHMEDABAD  ₹ 6,51,00,000
# 12           JAM NAGAR, JAMNAGAR    ₹ 32,50,000
# 13            MAKARBA, AHMEDABAD    ₹ 57,00,000
# 14       JASODA NAGAR, AHMEDABAD    ₹ 75,00,000
# 15              CHHANI, VADODARA    ₹ 17,50,000
# 16      ASHIRWAD NAGAR, VADODARA    ₹ 41,00,000
# 17         CHANDKHEDA, AHMEDABAD  ₹ 1,50,00,000
# ...

# %%
driver.get( "https://www.olx.in/jaipur_g4059123/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 39, 40, 40, 40)

# %%
import pandas as pd 
df4= pd.DataFrame({'Name':property_Name,'Prices':prices,'BHK':Bhk_type,'Years':years})
df4
# Out:
#                       Name         Prices  \
# 0   VAISHALI NAGAR, JAIPUR    ₹ 32,00,000
# 1       MANSAROVAR, JAIPUR    ₹ 99,50,000
# 2       MANSAROVAR, JAIPUR    ₹ 45,00,000
# 3   VAISHALI NAGAR, JAIPUR    ₹ 35,00,000
# 4       MANSAROVAR, JAIPUR  ₹ 1,34,00,000
# 5   VAISHALI NAGAR, JAIPUR    ₹ 95,00,000
# 6   VAISHALI NAGAR, JAIPUR  ₹ 1,40,00,000
# 7   VAISHALI NAGAR, JAIPUR    ₹ 40,00,000
# 8       MANSAROVAR, JAIPUR    ₹ 57,00,000
# 9       MANSAROVAR, JAIPUR    ₹ 48,00,000
# 10      MANSAROVAR, JAIPUR    ₹ 80,00,000
# 11      MANSAROVAR, JAIPUR    ₹ 67,50,000
# 12  VAISHALI NAGAR, JAIPUR    ₹ 23,50,000
# 13  VAISHALI NAGAR, JAIPUR    ₹ 38,00,000
# 14      MANSAROVAR, JAIPUR    ₹ 88,00,000
# 15        C SCHEME, JAIPUR  ₹ 3,30,00,000
# 16      MANSAROVAR, JAIPUR  ₹ 2,10,00,000
# 17  VAISHALI NAGAR, JAIPUR    ₹ 23,50,000
# 18  VAISHALI NAGAR, JAIPUR    ₹ 28,90,000
# 19  VAISHALI NAGAR, JAIPUR    ₹ 38,00,000
# 20  VAISHALI NAGAR, JAIPUR    ₹ 29,00,000
# ...

# %%
driver.get( "https://www.olx.in/bhopal_g4058901/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 40, 40, 40, 40)

# %%
import pandas as pd 
df1 = pd.DataFrame({'Name':property_Name,'Prices':prices,'BHK':Bhk_type, 'Type':Type,'Years':years})
df1
# Out:
#                                             Name         Prices  \
# 0                            SAKET NAGAR, BHOPAL    ₹ 65,00,000
# 1                           PANJABI BAGH, BHOPAL    ₹ 16,50,000
# 2                            NEHRU NAGAR, BHOPAL  ₹ 1,50,00,000
# 3   PADMANABH NAGAR HOUSING BOARD COLONY, BHOPAL    ₹ 33,00,000
# 4                           JAHANGIRABAD, BHOPAL    ₹ 22,99,999
# 5                           ARERA COLONY, BHOPAL     ₹ 2,00,000
# 6                               TT NAGAR, BHOPAL  ₹ 1,65,00,000
# 7                            SEMRA KALAN, BHOPAL     ₹ 7,50,000
# 8                     SARDAR PATEL NAGAR, BHOPAL    ₹ 27,90,000
# 9                            NEHRU NAGAR, BHOPAL    ₹ 78,00,000
# 10                           ROHIT NAGAR, BHOPAL    ₹ 80,00,000
# 11                         ASHOKA GARDEN, BHOPAL    ₹ 50,00,000
# 12                              MP NAGAR, BHOPAL    ₹ 40,00,000
# 13                          PUSHPA NAGAR, BHOPAL    ₹ 16,00,000
# ...

# %%
import pandas as pd 
df = pd.DataFrame({'Carpet':Carpet_area,'Property_name':property_Name,'Prices':price})
df
# Out:
#                                  Carpet  \
# 0  6 bds4 ba3,817 sqft - House for sale
# 1  4 bds2 ba2,074 sqft - House for sale
# 2  4 bds2 ba1,728 sqft - House for sale
# 3  4 bds3 ba3,367 sqft - House for sale
# 4  Studio 1 ba270 sqft - Condo for sale
# 5  4 bds2 ba1,698 sqft - House for sale
# 6  3 bds2 ba1,482 sqft - House for sale
# 7  Studio 1 ba598 sqft - Condo for sale
# 8  2 bds2 ba1,158 sqft - Condo for sale
#
#                                    Property_name    Prices
# 0            2540 Albany Dr, Kissimmee, FL 34758  $675,000
# 1    21675 E Camina Plata, Queen Creek, AZ 85142  $569,000
# 2                8514 N 46th St, Tampa, FL 33617  $324,999
# 3               3916 Esquire Dr, Plano, TX 75023  $800,000
# 4   255 W 24th St APT 308, Miami Beach, FL 33140  $290,000
# 5         2815 SUNSET BND, San Antonio, TX 78244  $265,000
# 6   3907 Thornbush Ln, New Port Richey, FL 34655  $299,900
# 7     475 Brickell Ave APT 4708, Miami, FL 33131  $450,000
# ...

# %%
driver.get( "https://www.olx.in/punjab_g2001170/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 40, 40, 40, 40)

# %%
import pandas as pd 
df5 = pd.DataFrame({'Name':property_Name,'Types':Type,'Prices':prices,'BHK':Bhk_type,'Years':years})
df5
# Out:
#                             Name                    Types         Prices  \
# 0             SECTOR 114, MOHALI   4 Bds - 4 Ba - 900 ft2    ₹ 98,45,000
# 1             SECTOR 116, MOHALI  3 Bds - 3 Ba - 1718 ft2    ₹ 64,90,000
# 2              SECTOR 78, MOHALI  4 Bds - 4 Ba - 1500 ft2  ₹ 2,15,00,000
# 3         UJALA NAGAR, JALANDHAR   2 Bds - 2 Ba - 900 ft2    ₹ 21,50,000
# 4             RAJIYA, RAJA SANSI  2 Bds - 3 Ba - 1400 ft2    ₹ 42,00,000
# 5             RAJIYA, RAJA SANSI  3 Bds - 4 Ba - 1750 ft2    ₹ 65,00,000
# 6           BAKARPUR 264, MOHALI  3 Bds - 3 Ba - 1822 ft2    ₹ 91,10,000
# 7           BAKARPUR 264, MOHALI  3 Bds - 3 Ba - 1745 ft2    ₹ 87,25,000
# 8           AIRPORT ROAD, MOHALI  3 Bds - 3 Ba - 2000 ft2    ₹ 85,00,000
# 9           AIRPORT ROAD, MOHALI  3 Bds - 3 Ba - 1995 ft2    ₹ 85,00,000
# 10            SECTOR 116, MOHALI  2 Bds - 2 Ba - 1199 ft2    ₹ 43,85,000
# 11            SECTOR 116, MOHALI  2 Bds - 2 Ba - 1206 ft2    ₹ 43,90,000
# ...

# %%
driver = webdriver.Chrome()

# %%
driver.get( "https://www.olx.in/navi-mumbai_g4059005/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 40, 40, 40, 40)

# %%
import pandas as pd 
df6 = pd.DataFrame({'Name':property_Name,'Types':Type,'Prices':prices,'BHK':Bhk_type,'Years':years})
df6
# Out:
#                        Name                    Types         Prices  \
# 0         ULWE, NAVI MUMBAI   1 Bds - 1 Ba - 630 ft2    ₹ 38,00,000
# 1       DAPOLI, NAVI MUMBAI   1 Bds - 2 Ba - 675 ft2    ₹ 45,00,000
# 2         ULWE, NAVI MUMBAI   1 Bds - 1 Ba - 660 ft2    ₹ 37,50,000
# 3         ULWE, NAVI MUMBAI  2 Bds - 2 Ba - 1160 ft2    ₹ 80,00,000
# 4         ULWE, NAVI MUMBAI   1 Bds - 1 Ba - 680 ft2    ₹ 54,00,000
# 5         ULWE, NAVI MUMBAI  2 Bds - 2 Ba - 1220 ft2    ₹ 91,50,000
# 6         ULWE, NAVI MUMBAI  2 Bds - 2 Ba - 1070 ft2    ₹ 71,00,000
# 7         ULWE, NAVI MUMBAI   1 Bds - 2 Ba - 740 ft2    ₹ 45,00,000
# 8       DAPOLI, NAVI MUMBAI   1 Bds - 1 Ba - 550 ft2    ₹ 66,00,000
# 9         ULWE, NAVI MUMBAI   1 Bds - 1 Ba - 615 ft2    ₹ 44,50,000
# 10        ULWE, NAVI MUMBAI   2 Bds - 2 Ba - 900 ft2    ₹ 17,00,000
# 11   KARANJADE, NAVI MUMBAI  3 Bds - 2 Ba - 1020 ft2    ₹ 22,00,000
# 12        ULWE, NAVI MUMBAI   2 Bds - 2 Ba - 688 ft2    ₹ 30,00,000
# ...

# %%
driver.get( "https://www.olx.in/nagpur_g4058998/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
import pandas as pd 
df7 = pd.DataFrame({'Name':property_Name,'Types':Type,'Prices':prices,'BHK':Bhk_type,'Years':years})
df7
# Out:
#                             Name                    Types         Prices  \
# 0                BORGAON, NAGPUR  2 Bds - 2 Ba - 1110 ft2    ₹ 39,00,000
# 1            CIVIL LINES, NAGPUR  3 Bds - 3 Ba - 1800 ft2  ₹ 1,10,00,000
# 2                BORGAON, NAGPUR  2 Bds - 2 Ba - 1020 ft2    ₹ 36,00,000
# 3          SHANKAR NAGAR, NAGPUR    2 Bds - 2 Ba - 00 ft2       ₹ 14,000
# 4          TUKDOJI CHOWK, NAGPUR   2 Bds - 2 Ba - 850 ft2    ₹ 33,00,000
# 5                 INDORA, NAGPUR   2 Bds - 1 Ba - 689 ft2    ₹ 19,60,975
# 6                 INDORA, NAGPUR   2 Bds - 2 Ba - 597 ft2    ₹ 23,17,887
# 7        AZAMSHAHA CHOWK, NAGPUR   4 Bds - 2 Ba - 600 ft2    ₹ 90,00,000
# 8            YADAV NAGAR, NAGPUR   3 Bds - 3 Ba - 700 ft2    ₹ 40,00,000
# 9   RANI DURGAWATI NAGAR, NAGPUR  1 Bds - 2 Ba - 9000 ft2    ₹ 24,00,000
# 10            SAKKARDARA, NAGPUR   1 Bds - 2 Ba - 500 ft2    ₹ 20,00,000
# 11            SAKKARDARA, NAGPUR   1 Bds - 1 Ba - 900 ft2    ₹ 32,00,000
# ...

# %%
driver.get( "https://www.olx.in/hyderabad_g4058526/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 39, 40, 40, 40)

# %%
import pandas as pd 
df8= pd.DataFrame({'Name':property_Name,'Prices':prices,'BHK':Bhk_type,'Years':years})
df8
# Out:
#                                            Name         Prices  \
# 0                       CZECH COLONY, HYDERABAD    ₹ 92,50,000
# 1                           AMEERPET, HYDERABAD  ₹ 2,10,00,000
# 2                          BALANAGAR, HYDERABAD    ₹ 40,00,000
# 3                            CHINTAL, HYDERABAD  ₹ 1,30,00,000
# 4   MPS AND MLA COLONY JUBILEE HILLS, HYDERABAD  ₹ 1,00,00,000
# 5                         KUKATPALLY, HYDERABAD     ₹ 5,00,000
# 6                       JAWAHARNAGAR, HYDERABAD  ₹ 1,40,00,000
# 7                         BALA NAGAR, HYDERABAD  ₹ 1,90,00,000
# 8                      ALLWYN COLONY, HYDERABAD    ₹ 65,00,000
# 9                         KUKATPALLY, HYDERABAD    ₹ 50,00,000
# 10                        KUKATPALLY, HYDERABAD    ₹ 53,00,000
# 11                        KUKATPALLY, HYDERABAD    ₹ 48,00,000
# 12                         BORABANDA, HYDERABAD    ₹ 50,00,000
# 13                        KUKATPALLY, HYDERABAD    ₹ 95,05,191
# ...

# %%
data_frames = [df1, df2, df3,df4,df5]

combined_df = pd.concat(data_frames, ignore_index=True)
print(combined_df)
# Out:
#                     Name         Prices   Years                    Types  \
# 0      SION EAST, MUMBAI  ₹ 1,60,00,000  MAY 28                      NaN
# 1     KURLA WEST, MUMBAI  ₹ 1,30,00,000  MAY 24                      NaN
# 2      KHAR EAST, MUMBAI    ₹ 25,00,000  JUN 06                      NaN
# 3        CHEMBUR, MUMBAI    ₹ 99,00,000   TODAY                      NaN
# 4    BANDRA WEST, MUMBAI  ₹ 2,95,00,000   TODAY                      NaN
# ..                   ...            ...     ...                      ...
# 195   SECTOR 127, MOHALI    ₹ 66,90,000   TODAY  3 Bds - 3 Ba - 1730 ft2
# 196   SECTOR 127, MOHALI    ₹ 66,90,000   TODAY  3 Bds - 3 Ba - 1730 ft2
# 197   SECTOR 115, MOHALI    ₹ 19,90,000   TODAY   1 Bds - 1 Ba - 650 ft2
# 198   SECTOR 116, MOHALI    ₹ 64,90,000   TODAY  3 Bds - 3 Ba - 1730 ft2
# 199   SECTOR 127, MOHALI    ₹ 43,90,000   TODAY  3 Bds - 3 Ba - 1350 ft2
#
#                                           BHK
# ...

# %%
df= pd.DataFrame({'Type':Type})
df
# Out:
#                          Type
# 0     2 Bds - 2 Ba - 1140 ft2
# 1   4+ Bds - 4+ Ba - 5000 ft2
# 2      1 Bds - 2 Ba - 450 ft2
# 3    4+ Bds - 4+ Ba - 900 ft2
# 4     2 Bds - 2 Ba - 1050 ft2
# 5      2 Bds - 2 Ba - 110 ft2
# 6   4+ Bds - 4+ Ba - 1800 ft2
# 7     2 Bds - 2 Ba - 1025 ft2
# 8     2 Bds - 2 Ba - 1150 ft2
# 9     2 Bds - 2 Ba - 1150 ft2
# 10    2 Bds - 2 Ba - 1000 ft2
# 11    2 Bds - 2 Ba - 1200 ft2
# 12    3 Bds - 2 Ba - 1509 ft2
# 13    2 Bds - 2 Ba - 1175 ft2
# 14    2 Bds - 2 Ba - 1235 ft2
# 15    2 Bds - 2 Ba - 1188 ft2
# 16    3 Bds - 2 Ba - 1333 ft2
# 17    4 Bds - 4 Ba - 1930 ft2
# 18    3 Bds - 3 Ba - 1920 ft2
# 19    2 Bds - 2 Ba - 1125 ft2
# 20    3 Bds - 2 Ba - 1150 ft2
# 21   4 Bds - 4+ Ba - 1956 ft2
# 22    3 Bds - 3 Ba - 2200 ft2
# 23     2 Bds - 2 Ba - 900 ft2
# 24   4+ Bds - 4+ Ba - 100 ft2
# 25      1 Bds - 1 Ba - 50 ft2
# 26     2 Bds - 2 Ba - 800 ft2
# 27     2 Bds - 2 Ba - 800 ft2
# 28    3 Bds - 3 Ba - 1840 ft2
# 29     2 Bds - 2 Ba - 800 ft2
# ...

# %%
driver.get( "https://www.olx.in/chandigarh_g2001149/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 40, 40, 40)

# %%
import pandas as pd 
df9= pd.DataFrame({'Name':property_Name,'Prices':prices,'BHK':Bhk_type,'Years':years})
df9
# Out:
#                                    Name          Prices  \
# 0                 SECTOR 48, CHANDIGARH   ₹ 3,05,00,000
# 1                 SECTOR 48, CHANDIGARH   ₹ 2,05,00,000
# 2                SECTOR 47C, CHANDIGARH   ₹ 1,95,00,000
# 3   CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 75,00,000
# 4   CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 85,00,000
# 5   CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 75,00,000
# 6   CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 70,00,000
# 7   CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 80,00,000
# 8                 SECTOR 43, CHANDIGARH   ₹ 2,25,00,000
# 9   CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 85,00,000
# 10  CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 85,00,000
# 11  CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 85,00,000
# 12  CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 75,00,000
# 13  CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 75,00,000
# 14  CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 70,00,000
# 15  CHANDIGARH AIRPORT AREA, CHANDIGARH     ₹ 70,00,000
# ...

# %%
df= pd.DataFrame({'Type':Type})
df
# Out:
#                        Type
# 0   4 Bds - 4 Ba - 2250 ft2
# 1   4 Bds - 3 Ba - 2350 ft2
# 2   2 Bds - 2 Ba - 1900 ft2
# 3   3 Bds - 3 Ba - 1800 ft2
# 4   3 Bds - 3 Ba - 1995 ft2
# 5   3 Bds - 3 Ba - 1850 ft2
# 6   3 Bds - 3 Ba - 1500 ft2
# 7   3 Bds - 3 Ba - 2000 ft2
# 8   3 Bds - 2 Ba - 1500 ft2
# 9   3 Bds - 3 Ba - 1850 ft2
# 10  3 Bds - 3 Ba - 1995 ft2
# 11  3 Bds - 3 Ba - 1995 ft2
# 12  3 Bds - 3 Ba - 1850 ft2
# 13  3 Bds - 3 Ba - 1800 ft2
# 14  3 Bds - 3 Ba - 1700 ft2
# 15  3 Bds - 3 Ba - 1600 ft2
# 16  3 Bds - 3 Ba - 1850 ft2
# 17  3 Bds - 3 Ba - 1850 ft2
# 18  3 Bds - 3 Ba - 1700 ft2
# 19  3 Bds - 3 Ba - 1600 ft2
# 20   2 Bds - 1 Ba - 550 ft2
# 21  3 Bds - 3 Ba - 1625 ft2
# 22  3 Bds - 3 Ba - 1600 ft2
# 23  3 Bds - 3 Ba - 1650 ft2
# 24   2 Bds - 2 Ba - 500 ft2
# 25  3 Bds - 3 Ba - 2000 ft2
# 26  3 Bds - 3 Ba - 1850 ft2
# 27  3 Bds - 3 Ba - 1600 ft2
# 28  3 Bds - 3 Ba - 1700 ft2
# 29  3 Bds - 3 Ba - 1800 ft2
# 30   2 Bds - 2 Ba - 950 ft2
# 31  3 Bds - 3 Ba - 1700 ft2
# ...

# %%
driver.get( "https://www.olx.in/surat_g4058727/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 40, 40, 40, 40)

# %%
import pandas as pd 
df9 = pd.DataFrame({'Name':property_Name,'Types':Type,'Prices':prices,'BHK':Bhk_type,'Years':years})
df9
# Out:
#                            Name                    Types       Prices  \
# 0              VADOD GAM, SURAT  2 Bds - 2 Ba - 1100 ft2  ₹ 17,50,000
# 1                BHESTAN, SURAT  4 Bds - 3 Ba - 1750 ft2  ₹ 65,11,111
# 2                BHESTAN, SURAT   1 Bds - 1 Ba - 657 ft2  ₹ 12,71,000
# 3          LIMBAYAT TOWN, SURAT   4+ Bds - 1 Ba - 25 ft2  ₹ 50,00,000
# 4                DINDOLI, SURAT   2 Bds - 2 Ba - 980 ft2  ₹ 18,87,900
# 5                DINDOLI, SURAT   1 Bds - 1 Ba - 615 ft2  ₹ 16,50,000
# 6                DINDOLI, SURAT   1 Bds - 1 Ba - 432 ft2  ₹ 20,51,000
# 7                DINDOLI, SURAT   2 Bds - 2 Ba - 925 ft2  ₹ 27,00,000
# 8                DINDOLI, SURAT  3 Bds - 3 Ba - 1350 ft2  ₹ 43,51,000
# 9                DINDOLI, SURAT  3 Bds - 3 Ba - 1521 ft2  ₹ 46,51,000
# 10               DINDOLI, SURAT   2 Bds - 2 Ba - 912 ft2  ₹ 34,51,000
# 11               DINDOLI, SURAT   1 Bds - 1 Ba - 540 ft2  ₹ 24,50,000
# ...

# %%
driver.get( "https://www.olx.in/kolkata_g4157275/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 40, 40, 40, 40)

# %%
import pandas as pd 
df10 = pd.DataFrame({'Name':property_Name,'Types':Type,'Prices':prices,'BHK':Bhk_type,'Years':years})
df10
# Out:
#                          Name                    Types         Prices  \
# 0        PARK CIRCUS, KOLKATA   2 Bds - 2 Ba - 650 ft2    ₹ 45,00,000
# 1      PICNIC GARDEN, KOLKATA   2 Bds - 1 Ba - 700 ft2    ₹ 21,00,000
# 2          BELEGHATA, KOLKATA   2 Bds - 1 Ba - 460 ft2    ₹ 12,00,000
# 3             TANGRA, KOLKATA   2 Bds - 2 Ba - 852 ft2    ₹ 35,78,400
# 4             TANGRA, KOLKATA   2 Bds - 2 Ba - 647 ft2    ₹ 27,17,400
# 5             TANGRA, KOLKATA   2 Bds - 2 Ba - 642 ft2    ₹ 26,96,400
# 6             TANGRA, KOLKATA   1 Bds - 1 Ba - 380 ft2    ₹ 15,96,000
# 7             TANGRA, KOLKATA   2 Bds - 2 Ba - 605 ft2    ₹ 25,41,000
# 8             TANGRA, KOLKATA   1 Bds - 1 Ba - 400 ft2    ₹ 16,80,000
# 9             TANGRA, KOLKATA   2 Bds - 2 Ba - 670 ft2    ₹ 28,14,000
# 10            TANGRA, KOLKATA   2 Bds - 2 Ba - 607 ft2    ₹ 25,49,400
# 11            TANGRA, KOLKATA   2 Bds - 2 Ba - 736 ft2    ₹ 30,91,200
# ...

# %%
driver.get( "https://www.olx.in/indore_g4058916/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 40, 40, 40, 40)

# %%
import pandas as pd 
df11 = pd.DataFrame({'Name':property_Name,'Types':Type,'Prices':prices,'BHK':Bhk_type,'Years':years})
df11
# Out:
#                              Name                      Types         Prices  \
# 0           KANADIYA ROAD, INDORE     3 Bds - 4 Ba - 600 ft2    ₹ 65,00,000
# 1                 NIPANIA, INDORE    3 Bds - 3 Ba - 1750 ft2    ₹ 95,00,000
# 2                 NIPANIA, INDORE    3 Bds - 4 Ba - 2000 ft2  ₹ 1,20,00,000
# 3        BAIRAATHY COLONY, INDORE    2 Bds - 1 Ba - 2400 ft2    ₹ 10,80,000
# 4       11 BANGLOW COLONY, INDORE    2 Bds - 1 Ba - 2400 ft2    ₹ 10,80,000
# 5           BOMBAY BAZAAR, INDORE    3 Bds - 2 Ba - 1500 ft2    ₹ 17,00,000
# 6         MAHALAXMI NAGAR, INDORE    2 Bds - 2 Ba - 1585 ft2    ₹ 96,00,000
# 7         MAHALAXMI NAGAR, INDORE    3 Bds - 2 Ba - 1550 ft2    ₹ 92,50,000
# 8              ALI COLONY, INDORE     2 Bds - 2 Ba - 450 ft2    ₹ 14,40,000
# 9                ALA PURA, INDORE     2 Bds - 3 Ba - 450 ft2    ₹ 14,40,000
# 10  AKHAND NAGAR SECTOR A, INDORE     2 Bds - 2 Ba - 425 ft2    ₹ 14,40,000
# ...

# %%
driver.get( "https://www.olx.in/ahmedabad_g4058677/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 39, 40, 40, 40)

# %%
import pandas as pd 
df12 = pd.DataFrame({'Name':property_Name,'Prices':prices,'BHK':Bhk_type,'Years':years})
df12
# Out:
#                              Name         Prices  \
# 0                RANIP, AHMEDABAD    ₹ 59,00,000
# 1                RANIP, AHMEDABAD  ₹ 1,60,00,000
# 2         MEGANI NAGAR, AHMEDABAD    ₹ 75,00,000
# 3          PANJARA POL, AHMEDABAD  ₹ 1,43,77,500
# 4          PANJARA POL, AHMEDABAD  ₹ 1,47,60,900
# 5              SHAHPUR, AHMEDABAD     ₹ 7,00,000
# 6        GULABAI TEKRA, AHMEDABAD  ₹ 1,35,00,000
# 7             JAMALPUR, AHMEDABAD    ₹ 25,00,000
# 8                PALDI, AHMEDABAD    ₹ 95,00,000
# 9             AMBAVADI, AHMEDABAD    ₹ 75,00,000
# 10               PALDI, AHMEDABAD    ₹ 71,00,000
# 11             KHOKHRA, AHMEDABAD    ₹ 44,00,000
# 12          BAPU NAGAR, AHMEDABAD     ₹ 7,50,000
# 13               RANIP, AHMEDABAD    ₹ 20,50,000
# 14             KHOKHRA, AHMEDABAD    ₹ 26,50,000
# 15        KESHAV NAGAR, AHMEDABAD  ₹ 5,00,00,000
# 16               RANIP, AHMEDABAD    ₹ 65,00,000
# 17  MITHAKHALI VILLAGE, AHMEDABAD  ₹ 1,22,52,000
# ...

# %%
driver.get( "https://www.olx.in/ujjain_g4058947/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 40, 40, 40, 40)

# %%
import pandas as pd 
df13= pd.DataFrame({'Name':property_Name,'Prices':prices,'BHK':Bhk_type,'Years':years})
df13
# Out:
#                                    Name         Prices  \
# 0                     NANDKHERA, UJJAIN    ₹ 35,00,000
# 1                     NANDKHERA, UJJAIN    ₹ 38,00,000
# 2                     NANDKHERA, UJJAIN    ₹ 23,51,000
# 3       PISHACHA MOCHAN TEERTHA, UJJAIN    ₹ 14,40,000
# 4                     NANDKHERA, UJJAIN    ₹ 50,00,000
# 5                  ADARSH NAGAR, UJJAIN    ₹ 10,80,000
# 6                KAMAL COLONY 2, UJJAIN    ₹ 14,40,000
# 7           CHAKRA TEERTHA GHAT, UJJAIN    ₹ 14,40,000
# 8                      NIMANWAS, UJJAIN    ₹ 14,40,000
# 9                     NANDKHERA, UJJAIN    ₹ 14,40,000
# 10                    MALANWASA, UJJAIN    ₹ 26,00,000
# 11                  MOHAN NAGAR, UJJAIN    ₹ 33,00,000
# 12           SURAJ NAGAR COLONY, UJJAIN    ₹ 30,00,000
# 13                 GOYALA KHURD, UJJAIN    ₹ 60,00,000
# 14          VASANT VIHAR COLONY, UJJAIN    ₹ 44,00,000
# 15              SANDIPANI NAGAR, UJJAIN    ₹ 23,99,800
# ...

# %%
driver.get( "https://www.olx.in/dehli_g5440113/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(Type),len(prices),len(years),len(Bhk_type)
# Out:
# (40, 40, 40, 40, 40)

# %%
import pandas as pd 
df14= pd.DataFrame({'Name':property_Name,'Prices':prices,'Type':Type,'BHK':Bhk_type,'Years':years})
df14
# Out:
#                            Name         Prices                       Type  \
# 0            KAMLA NAGAR, KALKA    ₹ 99,00,000   4+ Bds - 4 Ba - 2070 ft2
# 1   HOUSING BOARD COLONY, KALKA    ₹ 42,00,000    4 Bds - 2 Ba - 1000 ft2
# 2         RAILWAY COLONY, KALKA    ₹ 35,00,000    2 Bds - 1 Ba - 1000 ft2
# 3              TAKSAL, PARWANOO    ₹ 18,00,000    4 Bds - 1 Ba - 1850 ft2
# 4                BITNA, PINJORE    ₹ 22,00,000     2 Bds - 1 Ba - 800 ft2
# 5            KAMLA NAGAR, KALKA    ₹ 55,00,000    3 Bds - 2 Ba - 1150 ft2
# 6         KURARI MOHALLA, KALKA    ₹ 30,00,000    4+ Bds - 3 Ba - 700 ft2
# 7                BITNA, PINJORE    ₹ 75,00,000    2 Bds - 2 Ba - 1500 ft2
# 8                BITNA, PINJORE    ₹ 36,00,000     2 Bds - 2 Ba - 900 ft2
# 9     AMRAVATI ENCLAVE, PINJORE  ₹ 1,55,00,000    3 Bds - 3 Ba - 1575 ft2
# 10         RATPUR COLONY, KALKA    ₹ 20,00,000     2 Bds - 1 Ba - 600 ft2
# 11        CHAUNA CHOWK, PINJORE    ₹ 53,00,000    4 Bds - 3 Ba - 2800 ft2
# ...

# %%
driver.get( "https://www.olx.in/en-in/lucknow_g4059306/for-sale-houses-apartments_c1725")

# %%
property_Name = []
propertie_tags = driver.find_elements(By.XPATH, '//span[@class="_2VQu4"]')
for tag in propertie_tags:
    property_Name.append(tag.text)
    
    
Type = []
type_tags = driver.find_elements(By.XPATH, '//span[@class="YBbhy"]')
for tag in type_tags:
    Type.append(tag.text)
    
prices=[]
price_tags = driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for tag in price_tags:
    prices.append(tag.text)
    
Bhk_type =[]
bhk_tags = driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for tag in bhk_tags:
    Bhk_type.append(tag.text)
    
years=[]
year_tags = driver.find_elements(By.XPATH, '//span[@class="_2jcGx"]')
for tag in year_tags:
    years.append(tag.text)

# %%
len(property_Name),len(prices),len(years),len(Bhk_type),len(Type)
# Out:
# (40, 40, 40, 40, 32)

# %%
import pandas as pd 
df15= pd.DataFrame({'Name':property_Name,'Prices':prices,'BHK':Bhk_type,'Years':years})
df15
# Out:
#                                  Name         Prices  \
# 0              VIPUL KHAND 3, LUCKNOW  ₹ 1,65,00,000
# 1                CLAY SQUARE, LUCKNOW    ₹ 55,00,000
# 2               INDIRA NAGAR, LUCKNOW    ₹ 70,00,000
# 3                   LALABAGH, LUCKNOW    ₹ 24,50,000
# 4               INDIRA NAGAR, LUCKNOW    ₹ 80,00,000
# 5               INDIRA NAGAR, LUCKNOW    ₹ 32,00,000
# 6               INDIRA NAGAR, LUCKNOW    ₹ 75,00,000
# 7               INDIRA NAGAR, LUCKNOW    ₹ 98,00,000
# 8               INDIRA NAGAR, LUCKNOW    ₹ 72,00,000
# 9        PANDEY TOLA VILLAGE, LUCKNOW    ₹ 23,00,000
# 10                NISHATGANJ, LUCKNOW  ₹ 2,00,00,000
# 11              SHAKTI NAGAR, LUCKNOW    ₹ 60,00,000
# 12              INDIRA NAGAR, LUCKNOW  ₹ 1,45,00,000
# 13              SHAKTI NAGAR, LUCKNOW    ₹ 60,00,000
# 14                     CHOWK, LUCKNOW    ₹ 40,00,000
# 15                   NAKKHAS, LUCKNOW    ₹ 18,50,000
# 16              INDIRA NAGAR, LUCKNOW    ₹ 42,00,000
# ...

# %%
data_frames = [df1, df2, df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15]

combined_df = pd.concat(data_frames, ignore_index=True)
print(combined_df)

# %%
combined_df.to_csv('buy home.csv', index=False)
