# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df1= pd.read_csv(r"C:\Users\HP\Downloads\propertie.csv")
df2=pd.read_csv(r"C:\Users\HP\Downloads\Home propertie table 2.csv")
df3=pd.read_csv(r"C:\Users\HP\Downloads\Table 3.csv")



df= pd.concat([df1, df2, df3], axis=1)
df
# Out:
#       S.no    City Country State_code            Address         Landmark  \
# 0        1     Ncr   india         HR         Akshardham      City Center
# 1        2     Ncr   india         HR     Dilshad Colony        Near Mall
# 2        3     Ncr   india         HR     Dilshad Garden        Near Mall
# 3        4     Ncr   india         HR      I P Extension      City Center
# 4        5     Ncr   india         HR     Kondli Gharoli    Near Hospital
# ...    ...     ...     ...        ...                ...              ...
# 2995  2996  indore   india         MP       Sudama Nagar        Near Park
# 2996  2997  indore   india         MP           sector-2        Near Park
# 2997  2998  indore   india         MP      kalani nagar   Close to School
# 2998  2999  indore   india         MP  bhawanipur colony  Close to School
# 2999  3000  indore   india         MP         Azad Nagar      City Center
#
#        Bhk_type  Bath  Bedroom  Balcony  ...  Floor year_built  \
# ...

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\home properties project.csv")
df
# Out:
#       S.no    City State_code            Address  Bedroom  Bath  \
# 0        1     Ncr         HR         Akshardham        5     2
# 1        2     Ncr         HR     Dilshad Colony        5     2
# 2        3     Ncr         HR     Dilshad Garden        5     1
# 3        4     Ncr         HR      I P Extension        1     3
# 4        5     Ncr         HR     Kondli Gharoli        2     4
# ...    ...     ...        ...                ...      ...   ...
# 2995  2996  indore         MP       Sudama Nagar        2     2
# 2996  2997  indore         MP           sector-2        2     2
# 2997  2998  indore         MP      kalani nagar         3     2
# 2998  2999  indore         MP  bhawanipur colony        1     3
# 2999  3000  indore         MP         Azad Nagar        4     2
#
#              Landmark Country  Carpet_Area              Status  ...  \
# 0         City Center   india         2498       Ready to Move  ...
# ...

# %%
df.head()
# Out:
#   S.no City Country State_code         Address       Landmark   Bhk_type  \
# 0    1  Ncr   india         HR      Akshardham    City Center      2 BHK
# 1    2  Ncr   india         HR  Dilshad Colony      Near Mall  4 Bedroom
# 2    3  Ncr   india         HR  Dilshad Garden      Near Mall      3 BHK
# 3    4  Ncr   india         HR   I P Extension    City Center      3 BHK
# 4    5  Ncr   india         HR  Kondli Gharoli  Near Hospital      2 BHK
#
#    Bath  Bedroom  Balcony  ...  Floor year_built  Price per squre feet S.no  \
# 0     2        5        3  ...    2.0     2000.0            341.316722    1
# 1     2        5        1  ...    5.0     2021.0            289.360353    2
# 2     1        5        3  ...    2.0     2001.0            123.886596    3
# 3     3        1        2  ...    3.0     2003.0            368.656913    4
# 4     4        2        2  ...    2.0     2018.0            332.883504    5
#
# ...

# %%
df.tail()
# Out:
#       S.no    City Country State_code            Address         Landmark  \
# 2995  2996  indore   india         MP       Sudama Nagar        Near Park
# 2996  2997  indore   india         MP           sector-2        Near Park
# 2997  2998  indore   india         MP      kalani nagar   Close to School
# 2998  2999  indore   india         MP  bhawanipur colony  Close to School
# 2999  3000  indore   india         MP         Azad Nagar      City Center
#
#      Bhk_type  Bath  Bedroom  Balcony  ...  Floor year_built  \
# 2995    1 BHK     2        2        0  ...    2.0        NaN
# 2996    4 BHK     2        2        3  ...    2.0        NaN
# 2997     4BHK     2        3        2  ...    1.0        NaN
# 2998     4BHK     3        1        2  ...    2.0        NaN
# 2999     5BHK     2        4        2  ...    2.0        NaN
#
#       Price per squre feet  S.no  Face Direction  Ownership_Type  \
# 2995            269.392804  2996            East       Leasehold
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS(EDA)

# %%
#checking dimension of data set
df.shape
# Out:
# (3000, 24)

# %% [markdown]
# ###### This data set contain 3000 rows and 24columns.out of which 1 is target variable and remaining 23 is independent variables.

# %%
#checking data types of column
df.dtypes
# Out:
# S.no                      int64
# City                     object
# State_code               object
# Address                  object
# Bedroom                   int64
# Bath                      int64
# Landmark                 object
# Country                  object
# Carpet_Area               int64
# Status                   object
# Floor                   float64
# Booking_Amount            int64
# Furnished                object
# Balcony                   int64
# Transaction_Type         object
# Property Type            object
# Face Direction           object
# Bhk_type                 object
# Car_parking               int64
# Ownership_Type           object
# year_built              float64
# Size (sqft)               int64
# Price per squre feet    float64
# Total Price             float64
# dtype: object

# %% [markdown]
# ###### There are three different type of data present in data set (float64,int64,object)

# %%
df.isnull().sum()
# Out:
# S.no                     0
# City                     0
# State_code               0
# Address                  0
# Bedroom                  0
# Bath                     0
# Landmark                 0
# Country                  0
# Carpet_Area              0
# Status                   0
# Floor                   22
# Booking_Amount           0
# Furnished                0
# Balcony                  0
# Transaction_Type         0
# Property Type            0
# Face Direction           0
# Bhk_type                 8
# Car_parking              0
# Ownership_Type           0
# year_built              12
# Size (sqft)              0
# Price per squre feet     0
# Total Price              0
# dtype: int64

# %% [markdown]
# ###### In this dataset so many null values present remove null value. we are going to remove some columns those having maximum no of null values.

# %% [markdown]
# # Remove duplicated column

# %%
df = df.loc[:, ~df.columns.duplicated()]

# %%
df
# Out:
#       S.no    City State_code            Address  Bedroom  Bath  \
# 0        1     Ncr         HR         Akshardham        5     2
# 1        2     Ncr         HR     Dilshad Colony        5     2
# 2        3     Ncr         HR     Dilshad Garden        5     1
# 3        4     Ncr         HR      I P Extension        1     3
# 4        5     Ncr         HR     Kondli Gharoli        2     4
# ...    ...     ...        ...                ...      ...   ...
# 2995  2996  indore         MP       Sudama Nagar        2     2
# 2996  2997  indore         MP           sector-2        2     2
# 2997  2998  indore         MP      kalani nagar         3     2
# 2998  2999  indore         MP  bhawanipur colony        1     3
# 2999  3000  indore         MP         Azad Nagar        4     2
#
#              Landmark Country  Carpet_Area              Status  ...  \
# 0         City Center   india         2498       Ready to Move  ...
# ...

# %%
# find out the more information about the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   S.no                  3000 non-null   int64
#  1   City                  3000 non-null   object
#  2   State_code            3000 non-null   object
#  3   Address               3000 non-null   object
#  4   Bedroom               3000 non-null   int64
#  5   Bath                  3000 non-null   int64
#  6   Landmark              3000 non-null   object
#  7   Country               3000 non-null   object
#  8   Carpet_Area           3000 non-null   int64
#  9   Status                3000 non-null   object
#  10  Floor                 2978 non-null   float64
#  11  Booking_Amount        3000 non-null   int64
#  12  Furnished             3000 non-null   object
#  13  Balcony               3000 non-null   int64
#  14  Transaction_Type      3000 non-null   object
# ...

# %%
# using  visualize techinque  heatmap 
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# checking the value counts of each columns
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 1       1
# 2004    1
# 1995    1
# 1996    1
# 1997    1
#        ..
# 1003    1
# 1004    1
# 1005    1
# 1006    1
# 3000    1
# Name: S.no, Length: 3000, dtype: int64
#
#
# mumbai         657
# bengaluru      642
# pune           269
# chennai        183
# kolkata        160
# Ncr            136
# noida          108
# gurgaon        108
# indore         106
# ujjain         100
# hyderabad       82
# ahmedabad       79
# nagpur          61
# bhopal          61
# ghaziabad       60
# vadodara        43
# jaipur          29
# lucknow         27
# faridabad       25
# surat           24
# chandigarh      17
# bhubaneswar     13
# coimbatore      10
# Name: City, dtype: int64
#
#
# india    3000
# Name: Country, dtype: int64
#
#
# MH    987
# KA    642
# HR    437
# MP    267
# TN    193
# WB    160
# GJ    146
# TS     82
# RJ     29
# UP     27
# CH     17
# OD     13
# Name: State_code, dtype: int64
#
#
# Whitefield            27
# Electronic City       23
# ...

# %% [markdown]
# # Description of Data set

# %%
# used describe method its give information about the continuous column
df.describe()
# Out:
#               S.no         Bath     Bedroom      Balcony  Carpet_Area  \
# count  3000.000000  3000.000000  3000.00000  3000.000000  3000.000000
# mean   1500.500000     2.459333     2.91300     1.497000  1655.599333
# std     866.169729     1.124322     1.41731     1.112836   760.121681
# min       1.000000     1.000000     1.00000     0.000000   300.000000
# 25%     750.750000     1.000000     2.00000     0.000000  1000.000000
# 50%    1500.500000     2.000000     3.00000     2.000000  1624.000000
# 75%    2250.250000     3.000000     4.00000     2.000000  2315.000000
# max    3000.000000     4.000000     5.00000     3.000000  3000.000000
#
#              Floor   year_built  Price per squre feet  Car_parking  \
# count  2978.000000  2988.000000           3000.000000  3000.000000
# mean      2.681666  2011.899933            299.697120     1.500000
# std       1.368858     7.027972            114.863036     1.120901
# ...

# %% [markdown]
# ###### The  summary of data set look perfect sinces there is no negative values and invalid values present

# %% [markdown]
# ###### from above the description we can observer the following.

# %% [markdown]
# ######
# 1) The count of all the columns are same  which means there are no missing values present in the data set.
# 2) The mean value is greater then the meadian(50%)in carpet area columnan which means data is sknewed to right in these column
# 3) In the  column first quartile(25%)and second quratile(50%) not much of variance.
# 4) In the  data we can observe there is huge difference in (75%) and max column in some  column .Hence there are outlier present in the data.
# 5) In this data set some outlier present

# %% [markdown]
# # Data visualization

# %% [markdown]
# # Univariate Analysis
# In univariate analysis means we are performing the analysis on a single column.

# %%
# visualize count of the target variable
ax = sns.countplot(x ='Total Price',data =df)
print(df['Total Price'].value_counts())
# Out:
# 4.641907e+05    1
# 1.381613e+06    1
# 6.336817e+05    1
# 2.221483e+06    1
# 4.330258e+05    1
#                ..
# 8.942350e+05    1
# 8.589389e+05    1
# 1.441943e+06    1
# 7.967081e+05    1
# 1.003904e+06    1
# Name: Total Price, Length: 3000, dtype: int64

# %%
# Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.show()

# %%
# visualize count of the target variable
ax = sns.countplot(x ='Property Type',data =df)
print(df['Property Type'].value_counts())
# Out:
# Villa        803
# Apartment    765
# Studio       735
# Penthouse    696
# vila           1
# Name: Property Type, dtype: int64

# %%
# visualize count of the target variable
ax = sns.countplot(x ='Ownership_Type',data =df)
print(df['Ownership_Type'].value_counts())
# Out:
# Leasehold      1048
# Freehold       1021
# Condominium     931
# Name: Ownership_Type, dtype: int64

# %%
# visualize count of the target variable
ax = sns.countplot(x ='Face Direction',data =df)
print(df['Face Direction'].value_counts())
# Out:
# West         482
# Northeast    443
# North        404
# Southeast    362
# Northwest    356
# Southwest    334
# South        318
# East         301
# Name: Face Direction, dtype: int64

# %%
# visualize count of the target variable
ax = sns.countplot(x ='Furnished',data =df)
print(df['Furnished'].value_counts())
# Out:
# Furnished         1035
# Unfurnished        984
# Semi-Furnished     981
# Name: Furnished, dtype: int64

# %%
 ##visualize count of the target variable
ax = sns.countplot(x ='Carpet_Area',data =df)
print(df['Carpet_Area'].value_counts())
# Out:
# 1380    11
# 976     10
# 628     10
# 2264    10
# 2397    10
#         ..
# 2143     2
# 2611     2
# 1964     2
# 1554     1
# 833      1
# Name: Carpet_Area, Length: 837, dtype: int64

# %%
 ##visualize count of the target variable
ax = sns.countplot(x ='Status',data =df)
print(df['Status'].value_counts())
# Out:
# Ready to Move         1531
# Under Construction    1469
# Name: Status, dtype: int64

# %%
df.hist(figsize =(10,10),bins=50)
plt.show()

# %% [markdown]
# # Corrleation Between Target Variable And Independent Variable

# %%
cor =df.corr()
cor
# Out:
#                           S.no   Bedroom      Bath  Carpet_Area     Floor  \
# S.no                  1.000000 -0.005740  0.004924     0.001606 -0.009272
# Bedroom              -0.005740  1.000000 -0.060497    -0.001436  0.008516
# Bath                  0.004924 -0.060497  1.000000    -0.022707  0.021287
# Carpet_Area           0.001606 -0.001436 -0.022707     1.000000  0.001599
# Floor                -0.009272  0.008516  0.021287     0.001599  1.000000
# Booking_Amount        0.003417  0.000222  0.001031     0.036370  0.000042
# Balcony               0.032738  0.009454 -0.003962     0.025449  0.018137
# Car_parking          -0.032794  0.007241  0.008202    -0.009767 -0.012760
# year_built           -0.006433  0.016540  0.002142     0.023441  0.006538
# Size (sqft)          -0.008208  0.009481  0.007979    -0.013349 -0.034395
# Price per squre feet -0.028011 -0.000073  0.003104     0.014610 -0.002152
# Total Price          -0.026816  0.006123  0.005063    -0.002246 -0.030227
#
# ...

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize = (20,15))
sns.heatmap(df.corr(),linewidths = 0.1,fmt = ".1g", linecolor="black",annot = True,cmap ="YlGnBu")
plt.yticks(rotation =0);
plt.show()

# %% [markdown]
# ###### This heatmap show correlation matrix by visualazing the data .We can observe the relation between feature to feature and feature to label.

# %% [markdown]
# # Visualizing The Correlation Between Label And Features Using Bar Plot

# %%
plt.figure(figsize = (20,15))
df.corr()['Carpet_Area'].sort_values(ascending = False).drop(['Carpet_Area']).plot(kind ='bar',color ="m")
plt.xlabel('Feature',fontsize =15)
plt.ylabel('Target',fontsize =15)
plt.title("Correlation between label and features using bar plot",fontsize =20)
plt.show()

# %% [markdown]
# # FEATURE SELECTION

# %%
df.sample(5)
# Out:
#       S.no       City State_code          Address  Bedroom  Bath  \
# 2354  2355    kolkata         WB          Nayabad        5     1
# 1278  1279  bengaluru         KA  Electronic City        2     1
# 560    561     mumbai         MH          Vangani        4     1
# 822    823     mumbai         MH        Dronagiri        1     4
# 817    818     mumbai         MH          Belapur        2     2
#
#              Landmark Country  Carpet_Area              Status  ...  \
# 2354        Near Mall   india         1879  Under Construction  ...
# 1278    Near Hospital   india         2623  Under Construction  ...
# 560       City Center   india          754       Ready to Move  ...
# 822   Close to School   india         1626       Ready to Move  ...
# 817         Near Mall   india          779       Ready to Move  ...
#
#       Transaction_Type  Property Type Face Direction   Bhk_type Car_parking  \
# 2354            Resale         Studio      Northwest  2 Bedroom           1
# ...

# %%
df.drop(columns=['S.no'],inplace=True)

# %%
df.drop(columns=['Landmark'],inplace=True)

# %%
df.drop(columns=['Country'],inplace=True)

# %% [markdown]
# # Fillna Method

# %%
df['Floor'].fillna(df['Floor'].mean(), inplace=True)
df['year_built'].fillna(df['year_built'].mean(), inplace=True)
df['Bhk_type'].fillna(df['Bhk_type'].mode(), inplace=True)

# %%
df.isnull().sum()
# Out:
# City                    0
# State_code              0
# Address                 0
# Bedroom                 0
# Bath                    0
# Carpet_Area             0
# Status                  0
# Floor                   0
# Booking_Amount          0
# Furnished               0
# Balcony                 0
# Transaction_Type        0
# Property Type           0
# Face Direction          0
# Bhk_type                8
# Car_parking             0
# Ownership_Type          0
# year_built              0
# Size (sqft)             0
# Price per squre feet    0
# Total Price             0
# dtype: int64

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

df['Property Type'] = encoder.fit_transform(df['Property Type'])
df['Bhk_type'] = encoder.fit_transform(df['Bhk_type'])
df['Transaction_Type'] = encoder.fit_transform(df['Transaction_Type'])
df['Face Direction'] = encoder.fit_transform(df['Face Direction'])
                                              
df['Address'] = encoder.fit_transform(df['Address'])

df['City'] = encoder.fit_transform(df['City'])
df['State_code'] = encoder.fit_transform(df['State_code'])
df['Furnished'] = encoder.fit_transform(df['Furnished'])
df['Ownership_Type'] = encoder.fit_transform(df['Ownership_Type'])
df['Status'] = encoder.fit_transform(df['Status'])

# %%
df
# Out:
#       City  State_code  Address  Bedroom  Bath  Carpet_Area  Status  Floor  \
# 0        0           2       98        5     2         2498       0    2.0
# 1        0           2      485        5     2         1556       0    5.0
# 2        0           2      486        5     1         1386       0    2.0
# 3        0           2      715        1     3         2809       1    3.0
# 4        0           2      948        2     4         2759       0    2.0
# ...    ...         ...      ...      ...   ...          ...     ...    ...
# 2995    12           5     2148        2     2         2627       1    2.0
# 2996    12           5     2501        2     2         2323       0    2.0
# 2997    12           5     2468        3     2         2846       1    1.0
# 2998    12           5     2450        1     3         1785       1    2.0
# 2999    12           5      193        4     2         2045       1    2.0
#
# ...

# %% [markdown]
# # Separting Features and Label

# %% [markdown]
# # First target variable is Total Price

# %%
x= df.drop(["Total Price"],axis=1)
y= df["Total Price"]

# %%
print("independent variable")
x
# Out:
# independent variable
#       City  State_code  Address  Bedroom  Bath  Carpet_Area  Status  Floor  \
# 0        0           2       98        5     2         2498       0    2.0
# 1        0           2      485        5     2         1556       0    5.0
# 2        0           2      486        5     1         1386       0    2.0
# 3        0           2      715        1     3         2809       1    3.0
# 4        0           2      948        2     4         2759       0    2.0
# ...    ...         ...      ...      ...   ...          ...     ...    ...
# 2995    12           5     2148        2     2         2627       1    2.0
# 2996    12           5     2501        2     2         2323       0    2.0
# 2997    12           5     2468        3     2         2846       1    1.0
# 2998    12           5     2450        1     3         1785       1    2.0
# 2999    12           5      193        4     2         2045       1    2.0
#
# ...

# %%
print("dependent variable")
y
# Out:
# dependent variable
# 0       4.641907e+05
# 1       1.236147e+06
# 2       4.450007e+05
# 3       3.561226e+05
# 4       1.639784e+06
#             ...
# 2995    1.869586e+05
# 2996    1.263136e+06
# 2997    3.887357e+05
# 2998    1.178964e+06
# 2999    1.003904e+06
# Name: Total Price, Length: 3000, dtype: float64

# %% [markdown]
# # Feature Scaling Using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x),columns = x.columns)
print(x)
# Out:
#           City  State_code   Address   Bedroom      Bath  Carpet_Area  \
# 0    -1.524426   -0.921200 -1.559751  1.472753 -0.408610     1.108429
# 1    -1.524426   -0.921200 -1.042262  1.472753 -0.408610    -0.131053
# 2    -1.524426   -0.921200 -1.040925  1.472753 -1.298183    -0.354738
# 3    -1.524426   -0.921200 -0.734710 -1.349965  0.480962     1.517642
# 4    -1.524426   -0.921200 -0.423147 -0.644286  1.370535     1.451853
# ...        ...         ...       ...       ...       ...          ...
# 2995  0.190714    0.294103  1.181470 -0.644286 -0.408610     1.278167
# 2996  0.190714    0.294103  1.653494 -0.644286 -0.408610     0.878165
# 2997  0.190714    0.294103  1.609367  0.061394 -0.408610     1.566327
# 2998  0.190714    0.294103  1.585298 -1.349965  0.480962     0.170265
# 2999  0.190714    0.294103 -1.432719  0.767074 -0.408610     0.512373
#
#         Status     Floor  Booking_Amount  Furnished   Balcony  \
# 0    -0.979543 -0.499901       -0.932231   0.020727  1.350829
# ...

# %% [markdown]
# # Variance Information Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import  variance_inflation_factor
vif =pd.DataFrame()
vif["VIF value"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["features"] = x.columns
vif
# Out:
#     VIF value              features
# 0    1.062654                  City
# 1    1.055464            State_code
# 2    1.030746               Address
# 3    1.006823               Bedroom
# 4    1.008019                  Bath
# 5    1.008307           Carpet_Area
# 6    1.008064                Status
# 7    1.090241                 Floor
# 8    1.010485        Booking_Amount
# 9    1.006882             Furnished
# 10   1.004697               Balcony
# 11   1.004355      Transaction_Type
# 12   1.008836         Property Type
# 13   1.006145        Face Direction
# 14   1.097150              Bhk_type
# 15   1.007850           Car_parking
# 16   1.011374        Ownership_Type
# 17   1.005214            year_built
# 18   1.004798           Size (sqft)
# 19   1.005207  Price per squre feet

# %% [markdown]
# ###### The VIF value is not higher then 10 . so we don't need to solve the multicollinearity issues

# %% [markdown]
# # Modelling

# %% [markdown]
# # Finding the best random state

# %%
from sklearn.model_selection import train_test_split
from  sklearn.metrics import mean_absolute_error
from sklearn .metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
maxAccu = 0
maxRS =0
for i in range (0,1):
    x_train, x_test,y_train ,y_test = train_test_split(x , y, test_size =0.2,random_state =2)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    pred =lr.predict(x_test)
    acc= r2_score(y_test,pred)
    if acc>maxAccu:
        maxAcc = acc
        maxRS= i
    print("Maximum  r2 sscore  is",maxAccu," on random_state",maxRS)
# Out:
# Maximum  r2 sscore  is 0  on random_state 0

# %%
x_train, x_test,y_train ,y_test = train_test_split(x , y, test_size =0.30,random_state =maxRS)

# %% [markdown]
# # Regression Alorithm

# %%
from sklearn.linear_model import LinearRegression
from  sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from  sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# # Linear Regression

# %%
LR =LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training Data:',r2_score(y_test,pred_LR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_LR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_LR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.9050595618054735
# R2_score on training Data: 90.50595618054736
# Mean absolute Error:- 116372.24644703745
# Mean squared Error:- 116372.24644703745
# Root Mean squared  Error:- 153914.3680203856

# %% [markdown]
# ###### The r2 score value of Linear Regression model for train and test data is 90% both are same

# %%
plt.figure(figsize = (10,6))
plt.scatter(x= pred_LR, y = y_test,color ='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel('Actual',fontsize =15)
plt.ylabel('Predicted',fontsize =15)
plt.title("Linear Regression",fontsize =20)
plt.show()

# %% [markdown]
# # Random Forest Regressor

# %%
RFR = RandomForestRegressor()

RFR.fit(x_train,y_train)
pred_RFR = LR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training Data:',r2_score(y_test,pred_RFR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_RFR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_RFR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.9050595618054813
# R2_score on training Data: 90.50595618054813
# Mean absolute Error:- 116372.24644702603
# Mean squared Error:- 116372.24644702603
# Root Mean squared  Error:- 153914.36802037933

# %% [markdown]
# ###### In this model r2 score train and test data is same and mean error of both absolute and squred also same.

# %% [markdown]
# # K-Nearest Neighbor

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print('R2_score:',r2_score(y_test,pred_knn))
print('R2_score on training Data:',r2_score(y_test,pred_knn)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_knn))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_knn))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_score: 0.6568726865491934
# R2_score on training Data: 65.68726865491934
# Mean absolute Error:- 228491.8563551222
# Mean squared Error:- 228491.8563551222
# Root Mean squared  Error:- 292604.62906408263

# %% [markdown]
# ###### In this model mean squared and mean squred error then the previous two model.

# %% [markdown]
# # Lasso

# %%
lasso = Lasso()

lasso.fit(x_train,y_train)
pred_lasso = LR.predict(x_test)
pred_train = lasso.predict(x_train)
print('R2_score:',r2_score(y_test,pred_lasso))
print('R2_score on training Data:',r2_score(y_test,pred_lasso)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_lasso))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_lasso))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: 0.9050595618054813
# R2_score on training Data: 90.50595618054813
# Mean absolute Error:- 116372.24644702603
# Mean squared Error:- 116372.24644702603
# Root Mean squared  Error:- 153914.36802037933

# %% [markdown]
# ###### In  this model mean squared is less than knn model and r2 score test and train is also similar.

# %% [markdown]
# # ExtraTrees Regressor

# %%
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_ETR = etr.predict(x_test)
pred_train = etr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_ETR))
print('R2_score on training Data:',r2_score(y_test,pred_ETR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_ETR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_ETR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# R2_score: 0.9994120285126527
# R2_score on training Data: 99.94120285126526
# Mean absolute Error:- 7426.809624857337
# Mean squared Error:- 7426.809624857337
# Root Mean squared  Error:- 12112.441167836541

# %% [markdown]
# ###### Extra trees Regression give us best r2 score value.

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
# checking crosss validation score for Linear regression
score = cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_LR)-score.mean()*100))
# Out:
# [0.92050027 0.91928339 0.91118132 0.91603923 0.91884613]
# 0.9171700700555752
# Difference Between Accuracy and Cross Validation Score is_ -90.81194744375203

# %%
# checking crosss validation score for random foreset regressor
score = cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_RFR)-score.mean()*100))
# Out:
# [0.99886815 0.99895508 0.99902254 0.99895568 0.99884107]
# 0.9989285030302051
# Difference Between Accuracy and Cross Validation Score is_ -98.98779074121502

# %%
##checking crosss validation score for knn
score = cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_knn)-score.mean()*100))
# Out:
# [0.70010034 0.68143987 0.69278724 0.70253122 0.67204244]
# 0.6897802215722397
# Difference Between Accuracy and Cross Validation Score is_ -68.32114947067478

# %%
# checking crosss validation score for lasso
score = cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_lasso)-score.mean()*100))
# Out:
# [0.92050056 0.91928352 0.91118247 0.91603952 0.91884648]
# 0.9171705111060362
# Difference Between Accuracy and Cross Validation Score is_ -90.81199154879813

# %%
# checking crosss validation score for Extra tree Regressor
score = cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_ETR)-score.mean()*100))
# Out:
# [0.99957896 0.99967367 0.99965592 0.99961937 0.99960499]
# 0.9996265819881514
# Difference Between Accuracy and Cross Validation Score is_ -98.9632277355009

# %% [markdown]
# # Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
gscv = GridSearchCV(ExtraTreesRegressor(),parameter,cv =5)

# %%
gscv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]})

# %%
gscv.best_params_
# Out:
# {'max_depth': 30,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %%
Final_model = ExtraTreesRegressor(max_features='auto', max_depth =30, n_estimators=300,min_samples_leaf =1,min_samples_split=2)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print (acc*100)
# Out:
# 92.2989834997431

# %% [markdown]
# ###### Extra trees regressor model give us best r2  score  value

# %% [markdown]
# # second  target variable is property Type

# %%
x= df.drop(["Property Type"],axis=1)
y= df["Property Type"]

# %%
print("independent variable")
x
# Out:
# independent variable
#       City  State_code  Address  Bedroom  Bath  Carpet_Area  Status  Floor  \
# 0        0           2       98        5     2         2498       0    2.0
# 1        0           2      485        5     2         1556       0    5.0
# 2        0           2      486        5     1         1386       0    2.0
# 3        0           2      715        1     3         2809       1    3.0
# 4        0           2      948        2     4         2759       0    2.0
# ...    ...         ...      ...      ...   ...          ...     ...    ...
# 2995    12           5     2148        2     2         2627       1    2.0
# 2996    12           5     2501        2     2         2323       0    2.0
# 2997    12           5     2468        3     2         2846       1    1.0
# 2998    12           5     2450        1     3         1785       1    2.0
# 2999    12           5      193        4     2         2045       1    2.0
#
# ...

# %%
print("dependent variable")
y
# Out:
# dependent variable
# 0       3
# 1       0
# 2       1
# 3       2
# 4       0
#        ..
# 2995    1
# 2996    3
# 2997    3
# 2998    3
# 2999    4
# Name: Property Type, Length: 3000, dtype: int64

# %%
maxAccu = 0
maxRS =0
for i in range (0,1):
    x_train, x_test,y_train ,y_test = train_test_split(x , y, test_size =0.2,random_state =2)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    pred =lr.predict(x_test)
    acc= r2_score(y_test,pred)
    if acc>maxAccu:
        maxAcc = acc
        maxRS= i
    print("Maximum  r2 sscore  is",maxAccu," on random_state",maxRS)
# Out:
# Maximum  r2 sscore  is 0  on random_state 0

# %%
x_train, x_test,y_train ,y_test = train_test_split(x , y, test_size =0.30,random_state =maxRS)

# %% [markdown]
# # LinearRegression

# %%
LR =LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training Data:',r2_score(y_test,pred_LR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_LR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_LR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: -0.007314438518170929
# R2_score on training Data: -0.7314438518170929
# Mean absolute Error:- 1.0284631393184098
# Mean squared Error:- 1.0284631393184098
# Root Mean squared  Error:- 1.148700118423969

# %% [markdown]
# # RandomForestRegressor

# %%
RFR = RandomForestRegressor()

RFR.fit(x_train,y_train)
pred_RFR = LR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training Data:',r2_score(y_test,pred_RFR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_RFR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_RFR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: -0.007314438518170929
# R2_score on training Data: -0.7314438518170929
# Mean absolute Error:- 1.0284631393184098
# Mean squared Error:- 1.0284631393184098
# Root Mean squared  Error:- 1.148700118423969

# %% [markdown]
# # K-Nearest Neighbor

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print('R2_score:',r2_score(y_test,pred_knn))
print('R2_score on training Data:',r2_score(y_test,pred_knn)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_knn))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_knn))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_score: -0.2160950007952076
# R2_score on training Data: -21.60950007952076
# Mean absolute Error:- 1.081
# Mean squared Error:- 1.081
# Root Mean squared  Error:- 1.2621410380777578

# %% [markdown]
# # lasso

# %%
lasso = Lasso()

lasso.fit(x_train,y_train)
pred_lasso = LR.predict(x_test)
pred_train = lasso.predict(x_train)
print('R2_score:',r2_score(y_test,pred_lasso))
print('R2_score on training Data:',r2_score(y_test,pred_lasso)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_lasso))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_lasso))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: -0.007314438518170929
# R2_score on training Data: -0.7314438518170929
# Mean absolute Error:- 1.0284631393184098
# Mean squared Error:- 1.0284631393184098
# Root Mean squared  Error:- 1.148700118423969

# %% [markdown]
# # DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr = dtr.predict(x_test)
pred_train = dtr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_dtr))
print('R2_score on training Data:',r2_score(y_test,pred_dtr)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_dtr))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_dtr))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score: -0.9034087896941103
# R2_score on training Data: -90.34087896941104
# Mean absolute Error:- 1.23
# Mean squared Error:- 1.23
# Root Mean squared  Error:- 1.5790292376436015

# %% [markdown]
# # ExtraTreesRegressor

# %%
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_ETR = etr.predict(x_test)
pred_train = etr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_ETR))
print('R2_score on training Data:',r2_score(y_test,pred_ETR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_ETR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_ETR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# R2_score: -0.05762387743200992
# R2_score on training Data: -5.762387743200992
# Mean absolute Error:- 1.0321166666666666
# Mean squared Error:- 1.0321166666666666
# Root Mean squared  Error:- 1.1770360373978925

# %% [markdown]
# # Third  target variable is carpet Area

# %%
x= df.drop(["Carpet_Area"],axis=1)
y= df["Carpet_Area"]

# %%
maxAccu = 0
maxRS =0
for i in range (0,1):
    x_train, x_test,y_train ,y_test = train_test_split(x , y, test_size =0.2,random_state =2)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    pred =lr.predict(x_test)
    acc= r2_score(y_test,pred)
    if acc>maxAccu:
        maxAcc = acc
        maxRS= i
    print("Maximum  r2 sscore  is",maxAccu," on random_state",maxRS)
# Out:
# Maximum  r2 sscore  is 0  on random_state 0

# %%
x_train, x_test,y_train ,y_test = train_test_split(x , y, test_size =0.30,random_state =maxRS)

# %% [markdown]
# # LinearRegression

# %%
LR =LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training Data:',r2_score(y_test,pred_LR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_LR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_LR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: -0.009129846647456974
# R2_score on training Data: -0.9129846647456974
# Mean absolute Error:- 652.8663613167114
# Mean squared Error:- 652.8663613167114
# Root Mean squared  Error:- 759.0694647669677

# %% [markdown]
# # ExtraTreesRegressor

# %%
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_ETR = etr.predict(x_test)
pred_train = etr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_ETR))
print('R2_score on training Data:',r2_score(y_test,pred_ETR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_ETR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_ETR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# R2_score: -0.058198304950930924
# R2_score on training Data: -5.819830495093092
# Mean absolute Error:- 662.4163333333332
# Mean squared Error:- 662.4163333333332
# Root Mean squared  Error:- 777.305116566061

# %% [markdown]
# # Random Forest Regressor

# %%
RFR = RandomForestRegressor()

RFR.fit(x_train,y_train)
pred_RFR = LR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training Data:',r2_score(y_test,pred_RFR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_RFR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_RFR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: -0.009129846647456974
# R2_score on training Data: -0.9129846647456974
# Mean absolute Error:- 652.8663613167114
# Mean squared Error:- 652.8663613167114
# Root Mean squared  Error:- 759.0694647669677

# %% [markdown]
# # K-Nearest Neighbor

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print('R2_score:',r2_score(y_test,pred_knn))
print('R2_score on training Data:',r2_score(y_test,pred_knn)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_knn))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_knn))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_score: -0.22096130077791987
# R2_score on training Data: -22.096130077791987
# Mean absolute Error:- 702.8188888888889
# Mean squared Error:- 702.8188888888889
# Root Mean squared  Error:- 834.947070178703

# %% [markdown]
# # DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr = dtr.predict(x_test)
pred_train = dtr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_dtr))
print('R2_score on training Data:',r2_score(y_test,pred_dtr)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_dtr))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_dtr))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score: -1.012471427100326
# R2_score on training Data: -101.24714271003259
# Mean absolute Error:- 875.2044444444444
# Mean squared Error:- 875.2044444444444
# Root Mean squared  Error:- 1071.9458744627816

# %% [markdown]
# # lasso

# %%
lasso = Lasso()

lasso.fit(x_train,y_train)
pred_lasso = LR.predict(x_test)
pred_train = lasso.predict(x_train)
print('R2_score:',r2_score(y_test,pred_lasso))
print('R2_score on training Data:',r2_score(y_test,pred_lasso)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_lasso))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_lasso))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: -0.009129846647456974
# R2_score on training Data: -0.9129846647456974
# Mean absolute Error:- 652.8663613167114
# Mean squared Error:- 652.8663613167114
# Root Mean squared  Error:- 759.0694647669677

# %% [markdown]
# # Ridge

# %%
rd= Ridge()

rd.fit(x_train,y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print('R2_score:',r2_score(y_test,pred_rd))
print('R2_score on training Data:',r2_score(y_test,pred_rd)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_rd))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_rd))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_score: -0.009115405417228217
# R2_score on training Data: -0.9115405417228217
# Mean absolute Error:- 652.8657380036979
# Mean squared Error:- 652.8657380036979
# Root Mean squared  Error:- 759.0640333865786

# %% [markdown]
# # Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param ={'alpha':[1.0,0.5,.4,2],
        'fit_intercept':[True,False],
        'precompute':[True,False],
        'warm_start':[True,False],
       'random_state':[1,4,10,20]
       }
gscv = GridSearchCV(Lasso(),param,cv =5)
gscv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1.0, 0.5, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'precompute': [True, False],
#                          'random_state': [1, 4, 10, 20],
#                          'warm_start': [True, False]})

# %%
gscv.best_params_
# Out:
# {'alpha': 2,
#  'fit_intercept': False,
#  'precompute': False,
#  'random_state': 1,
#  'warm_start': True}

# %%
Model = Lasso(alpha = 2,fit_intercept =False,precompute=False,random_state =1,warm_start =True)

# %%
Model.fit(x_train,y_train)
pred = Model.predict(x_test)

print('R2_score:',r2_score(y_test,pred))
print('R2_score on training Data:',r2_score(y_test,pred)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred))
print('Mean squared Error:-',mean_absolute_error(y_test,pred))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: -0.008287913541076275
# R2_score on training Data: -0.8287913541076275
# Mean absolute Error:- 652.7911909518614
# Mean squared Error:- 652.7911909518614
# Root Mean squared  Error:- 758.7527468193035

# %% [markdown]
# # Save The Model

# %%
import joblib
joblib.dump(model,"REAL ESTATE CAPSTON BUY HOME PROPERTIE .pkl")
# Out:
# ['REAL ESTATE CAPSTON BUY HOME PROPERTIE .pkl']

# %% [markdown]
# # Predict The Model

# %%
# lets load the save model and predict it 
model =joblib.load("REAL ESTATE CAPSTON BUY HOME PROPERTIE.pkl")
prediction = model.predict(x_test)
prediction
# Out:
# array([1710.71897436, 1688.10772329, 1633.39410131, 1563.3131706 ,
#        1601.08776844, 1605.78715901, 1736.64404102, 1652.3931019 ,
#        1544.77249928, 1601.70861896, 1652.73294181, 1629.54474964,
#        1753.95089245, 1650.12481781, 1706.01595923, 1852.00737848,
#        1721.14596514, 1555.66750691, 1799.53402408, 1582.63466819,
#        1546.47792128, 1755.92878011, 1589.60776652, 1581.05576295,
#        1654.00031281, 1724.41083384, 1725.76194683, 1608.73275977,
#        1581.91937839, 1743.79581654, 1703.32471417, 1599.19252397,
#        1720.51858922, 1556.04842688, 1626.86851817, 1660.22203051,
#        1583.33362257, 1771.95388647, 1658.51708625, 1732.55896746,
#        1691.55141515, 1605.02307097, 1742.90719258, 1737.39985346,
#        1713.02311709, 1630.43160081, 1722.61586522, 1610.00840912,
#        1813.74840847, 1505.31044772, 1652.66930895, 1716.21769434,
#        1747.2500021 , 1673.9499282 , 1693.75926115, 1766.22061777,
# ...

# %%
a = np.array(y_test)
df = pd.DataFrame()
df["predicted"] = prediction
df["original"] = a
df
# Out:
#        predicted  original
# 0    1710.718974       916
# 1    1688.107723      1837
# 2    1633.394101      1837
# 3    1563.313171       678
# 4    1601.087768      2523
# ..           ...       ...
# 895  1655.229584      1580
# 896  1719.357879      2714
# 897  1716.380061       407
# 898  1622.862818      2504
# 899  1703.812342      1636
#
# [900 rows x 2 columns]

# %% [markdown]
# # project Description

# %% [markdown]
# ###### we have three target variable carpet area ,total price and Property type we work on  this target variable

# %%
1.In this data set first we import libaries and then perform EdA part

2.check null values and plot headmap that give idea for null value present or not in this data set null value present we treat null value with filna method.

3.performing both statistical and data visualization techinque.

4.check correlation and plot headmap

5.delete unnecessary column  and apply label encoding in some column .

6.select features and label this time total price our target variable.

7.Features selection

8.data standarization and normalization

9.Vif Method two check multicolinearity issues .

10.creation of train and test data set using algorithm parameters

11.model training using machine learning algorithm we used regression algorithm .

12.calculation of model accuracy both training and test accuracy.check cross validation

13.select best model and perform hyperparameter tunning to a better accuracy .

14.Again select features and label and this time property type  is our target variable we work on this create train and test data apply  regression  algorithm in train and test data
.
15.Again select features and label and this time carpet area   is our target variable we work on this create train and test data apply  regression  algorithm in train and test data
16.saving the created model file.
