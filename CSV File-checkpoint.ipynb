# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\home properties project.csv")
df
# Out:
#       S.no    City State_code            Address  Bedroom  Bath  \
# 0        1     Ncr         HR         Akshardham        5     2
# 1        2     Ncr         HR     Dilshad Colony        5     2
# 2        3     Ncr         HR     Dilshad Garden        5     1
# 3        4     Ncr         HR      I P Extension        1     3
# 4        5     Ncr         HR     Kondli Gharoli        2     4
# ...    ...     ...        ...                ...      ...   ...
# 2995  2996  indore         MP       Sudama Nagar        2     2
# 2996  2997  indore         MP           sector-2        2     2
# 2997  2998  indore         MP      kalani nagar         3     2
# 2998  2999  indore         MP  bhawanipur colony        1     3
# 2999  3000  indore         MP         Azad Nagar        4     2
#
#              Landmark Country  Carpet_Area              Status  ...  \
# 0         City Center   india         2498       Ready to Move  ...
# ...

# %%
# Load the CSV file
csv_file_path = r"C:\Users\HP\Downloads\home properties project.csv"

df = pd.read_csv(csv_file_path)

# Extract the desired columns
columns = ['S.no','City','Country','State_code','Address','Landmark','Bhk_type','Bath','Bedroom','Balcony']
df_extracted = df[columns]

# Save the extracted columns to a new CSV file
new_csv_file_path = r'C:\Users\HP\Downloads\data1.csv'
df_extracted.to_csv(new_csv_file_path, index=False)

print(f'Table 1 {new_csv_file_path}')
# Out:
# Table 1 C:\Users\HP\Downloads\data1.csv

# %%
# Load the CSV file
csv_file_path = r"C:\Users\HP\Downloads\home properties project.csv"
df = pd.read_csv(csv_file_path)

# Extract the desired columns
columns = ['S.no','Status','Carpet_Area','Transaction_Type','Floor','year_built','Price per squre feet'] 

df_extracted = df[columns]

# Save the extracted columns to a new CSV file
new_csv_file_path = r'C:\Users\HP\Downloads\real_estate_data.csv'
df_extracted.to_csv(new_csv_file_path, index=False)

print(f'Table 2 {new_csv_file_path}')
# Out:
# Table 2 C:\Users\HP\Downloads\real_estate_data.csv

# %%
# Load the CSV file
csv_file_path = r"C:\Users\HP\Downloads\home properties project.csv"
df = pd.read_csv(csv_file_path)

# Extract the desired columns
columns_to_extract = ['S.no','Face Direction','Ownership_Type','Furnished','Car_parking','Booking_Amount','Total Price'] 

df_extracted = df[columns_to_extract]

# Save the extracted columns to a new CSV file
new_csv_file_path = r'C:\Users\HP\Downloads\data.csv'
df_extracted.to_csv(new_csv_file_path, index=False)

print(f'Table 3 {new_csv_file_path}')
# Out:
# Table 3 C:\Users\HP\Downloads\data.csv
